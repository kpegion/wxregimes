# %% [markdown]
# # This is the third step in reproducing the cluster analysis from Sara and David following Amini et al 2019
# https://doi.org/10.1007/s00382-018-4409-7
#
# This program:

# %%
import xarray as xr
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cartopy.crs as ccrs
import cartopy.mpl.ticker as cticker

from eofs.multivariate.standard import MultivariateEof

# %% [markdown]
# ### Define Input and Output Data

# %%
# Input
path='/project/predictability/kpegion/wxregimes/era-interim/'
fname='erai.z500_u250_pna_5dyrm_DJF.1980-2015.anoms.nc'

# Output
outfile='erai.z500_u250_pna_5dyrm_DJF.1980-2015.pcs.nc'

# %% [markdown]
# ### Define constants

# %%
npcs=12

# %% [markdown]
# ### Read Data

# %%
print(path+fname)
ds=xr.open_dataset(path+fname,decode_times=False)
ds['z500']=ds['z500']/9.81
# Out:
# /project/predictability/kpegion/wxregimes/era-interim/erai.z500_u250_pna_5dyrm_DJF.1980-2015.anoms.nc

# %%
plt.contourf(ds['z500'][0,:,:])
plt.colorbar()

ds['z500'].var(dim='time').mean(dim=['lat','lon'])
ds['u250'].var(dim='time').mean(dim=['lat','lon'])
# Out:
# <xarray.DataArray 'u250' ()>
# array(75.68708922)

# %%
plt.plot(ds['z500'][:,12,25])

# %% [markdown]
# ### Setup Latitude Weighting

# %%
coslat = np.cos(np.deg2rad(ds['lat'].values))
weights_array = np.sqrt(coslat)[:, np.newaxis]

# %% [markdown]
# ### Do the latitude weighting myself first, then check nomalization

# %%
ds['z500']=ds['z500']*weights_array
ds['u250']=ds['u250']*weights_array

# %%
norm_z500=np.sqrt((ds['z500'].var(dim='time')).mean(dim=['lat','lon']))
ds['z500']=ds['z500']/norm_z500
norm_u250=np.sqrt(ds['u250'].var(dim='time').mean(dim=['lat','lon']))
ds['u250']=ds['u250']/norm_u250

# %%
print(norm_z500.values*norm_z500.values)
print(norm_u250.values*norm_u250.values)
# Out:
# 3051.209487716653
# 51.75077102928162

# %% [markdown]
# ### Create the eof solver with latitude weighting

# %%
solver=MultivariateEof([ds['z500'].values,ds['u250'].values])

# %% [markdown]
# ### Get the EOF (spatial pattern) as a check

# %%
#eof1_list=solver.eofsAsCovariance(neofs=12)
eof1_list=solver.eofs(neofs=12,eofscaling=0)
print(eof1_list[0].shape)
print(eof1_list[0][0,:,:])
# Out:
# (12, 22, 53)
# [[ 4.28933726e-03  4.44977859e-03  4.59730078e-03 ...  3.71666897e-03
#    3.65018092e-03  3.57538994e-03]
#  [ 6.08386914e-03  6.27419149e-03  6.41957348e-03 ...  4.63396688e-03
#    4.59763805e-03  4.57961844e-03]
#  [ 7.61982993e-03  7.81431647e-03  7.94614879e-03 ...  5.96186549e-03
#    6.00778798e-03  6.06164811e-03]
#  ...
#  [-8.74274920e-03 -8.64716247e-03 -8.51974031e-03 ... -9.16908502e-03
#   -7.46724331e-03 -5.71021728e-03]
#  [-4.25091485e-03 -3.89526249e-03 -3.48461155e-03 ... -3.97488441e-03
#   -2.54342651e-03 -1.06071877e-03]
#  [-9.40304674e-04 -4.26501498e-04  1.42943264e-04 ... -2.22578961e-05
#    1.14603574e-03  2.35104082e-03]]

# %% [markdown]
# ### Plot the first EOF (spatial pattern) as a check; should be Aleutian Low associated with ENSO

# %%
cm = 180
proj = ccrs.PlateCarree(central_longitude=cm)
minlon = -30 + cm
maxlon = +120 + cm
lat_labels=np.arange(20,80,20)
lon_labels=np.arange(150,330,30)
extent=[minlon,maxlon,20,80]

# %%
levs=np.arange(-0.1,0.07,0.02)
z500_eof1=eof1_list[0][0,:,:]/weights_array
ax=plt.axes(projection=proj)
ax.set_extent(extent,crs=ccrs.PlateCarree())
cs=ax.contourf(ds['lon'],ds['lat'],
               z500_eof1,levs,
               transform=ccrs.PlateCarree(),
              extend='both')
ax.set_title('EOF1 z500')
ax.coastlines()
plt.colorbar(cs)

# %%
levs=np.arange(-0.045,0.1,0.015)
u250_eof1=eof1_list[1][0,:,:]/weights_array
ax=plt.axes(projection=proj)
ax.set_extent(extent,crs=ccrs.PlateCarree())
cs=ax.contourf(ds['lon'],ds['lat'],
               u250_eof1,levs,
               transform=ccrs.PlateCarree(),
               extend='both')
ax.set_title('EOF1 u250')
ax.coastlines()
plt.colorbar(cs)

# %%
levs=np.arange(-0.06,0.08,0.02)
z500_eof2=eof1_list[0][1,:,:]/weights_array
ax=plt.axes(projection=proj)
ax.set_extent(extent,crs=ccrs.PlateCarree())
cs=ax.contourf(ds['lon'],ds['lat'],
               z500_eof2,levs,
               transform=ccrs.PlateCarree(),
               extend='both')
ax.set_title('EOF2 z500')
ax.coastlines()
plt.colorbar(cs)

# %%
levs=np.arange(-0.075,0.07,0.015)
u250_eof2=eof1_list[1][1,:,:]/weights_array
ax=plt.axes(projection=proj)
ax.set_extent(extent,crs=ccrs.PlateCarree())
cs=ax.contourf(ds['lon'],ds['lat'],
               u250_eof2,levs,
               transform=ccrs.PlateCarree())
ax.set_title('EOF2 u250')
ax.coastlines()
plt.colorbar(cs)

# %% [markdown]
# ### Get the First 12 PCs

# %%
pcs = solver.pcs()
pcs = solver.pcs(npcs=npcs, pcscaling=0)
#pcs = solver.pcs(npcs=npcs)
pcs.shape
# Out:
# (3150, 12)

# %%
weights_array
# Out:
# array([[0.42628707],
#        [0.47892617],
#        [0.52580996],
#        [0.56826623],
#        [0.6071337 ],
#        [0.64297923],
#        [0.67620496],
#        [0.70710678],
#        [0.73590862],
#        [0.76278379],
#        [0.78786887],
#        [0.81127308],
#        [0.83316025],
#        [0.85344652],
#        [0.87227242],
#        [0.88968737],
#        [0.9057326 ],
#        [0.92044264],
#        [0.93384649],
#        [0.94596854],
#        [0.95682926],
#        [0.96644584]])

# %%
plt.plot(pcs[0:89,0])
print(pcs[:,0].mean())
print(pcs[:,0].std())
print(pcs[:,0].var())
# Out:
# 1.4436423837665528e-16
# 22.1346343566328
# 489.94203810182916

# %% [markdown]
# ### Find out how much variance is explained by first 12 PCs; Amini and Straus found about 80%

# %%
variance_fractions = solver.varianceFraction(neigs=npcs)

# %%
variance_fractions.sum()
# Out:
# 0.7658855797850364

# %% [markdown]
# ### Put PCs into `xr.Dataset`

# %%
# Create a new xarray dataset for z500
pcs_ds=xr.DataArray(pcs,
                    coords={'time': ds['time'].values,
                            'pcnum':np.arange(npcs)},
                            dims=['time','pcnum'])        
pcs_ds=pcs_ds.to_dataset(name='pcs')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-7a16f50cb7af> in <module>
#       3                     coords={'time': ds['time'].values,
#       4                             'pcnum':np.arange(npcs)},
# ----> 5                             dims=['time','pcnum'])
#       6 pcs_ds=pcs_ds.to_dataset(name='pcs')
#
# ~/.conda/envs/aoes/lib/python3.6/site-packages/xarray/core/dataarray.py in __init__(self, data, coords, dims, name, attrs, indexes, fastpath)
#     342             data = _check_data_shape(data, coords, dims)
#     343             data = as_compatible_data(data)
# --> 344             coords, dims = _infer_coords_and_dims(data.shape, coords, dims)
#     345             variable = Variable(dims, data, attrs, fastpath=True)
#     346             indexes = dict(
#
# ~/.conda/envs/aoes/lib/python3.6/site-packages/xarray/core/dataarray.py in _infer_coords_and_dims(shape, coords, dims)
#     153                     "conflicting sizes for dimension %r: "
#     154                     "length %s on the data but length %s on "
# --> 155                     "coordinate %r" % (d, sizes[d], s, k)
#     156                 )
#     157
#
# ValueError: conflicting sizes for dimension 'pcnum': length 1 on the data but length 12 on coordinate 'pcnum'

# %%
pcs_ds

# %%
pcs_ds.to_netcdf(path+outfile)
